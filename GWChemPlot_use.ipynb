# %% [markdown]
# # GW chemistry plots
# https://github.com/jyangfsu/WQChartPy
# ## Data

# %%
import pandas as pd
import piper
import schoeller
import stiff
import importlib

# %%
importlib.reload(piper)
# Out:
# <module 'stiff' from 'C:\\Users\\solis\\Documents\\DEV\\python3\\Graphs\\wq_plots\\stiff.py'>

# %%
data_path = './data/data_template.csv'
df = pd.read_csv(data_path)
df
# Out:
#     Sample Label  Color Marker  Size  Alpha   pH   Ca  Mg  Na    K  HCO3  CO3  \
# 0  sample1    C1    red      o    30    0.6  7.8   32   6  28  2.8    73    0
# 1  sample2    C2  green      o    30    0.6  7.6   46  11  17  0.7   201    0
# 2  sample3    C2  green      o    30    0.6  7.5   54  11  16  2.4   207    0
# 3  sample4    C3   blue      o    30    0.6  7.7   50  11  25  2.8   244    0
# 4  sample5    C3   blue      o    30    0.6  7.4   50  22  25  0.5   305    0
# 5  sample6    C1    red      o    30    0.6  7.1  134  21  39  6.4   275    0
#
#    Cl  SO4  TDS
# 0  43   48  233
# 1  14    9  299
# 2  18   10  377
# 3  18    9  360
# 4  11    9  424
# 5  96  100  673

# %%
figname = './out/piper_data_template.png'

piper.plot(df, figname=figname)
# Out:
# Trilinear Piper plot created

# %%
figname = './out/schoeller_data_template.png'

schoeller.plot(df, figname=figname)
# Out:
# Schoeller plot created

# %%
# importlib.reload(stiff)

figname = './out/stiff_data_template.png'

stiff.plot(df, figname=figname)
# Out:
# stiff_data_template_sample1.png
# stiff_data_template_sample2.png
# stiff_data_template_sample3.png
# stiff_data_template_sample4.png
# stiff_data_template_sample5.png
# stiff_data_template_sample6.png
# Stiff plot created

# %%
for idx, row in df.iterrows():
    print(idx, row.Sample)
# Out:
# 0 sample1
# 1 sample2
# 2 sample3
# 3 sample4
# 4 sample5
# 5 sample6
