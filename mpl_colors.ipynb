# %% [markdown]
# # Colores de matplotlib en el módulo mpl_colors
#
# Matplotlib permite representar cualquier color a través de su código de color (https://matplotlib.org/stable/tutorials/colors/colors.html)
#
# A efectos de obtener las mejores representaciones, se crean los denominados mapas de color (colormapas), que son generalmente transiciones suaves entre varios colores. Hay muchos colormaps y cada uno tiene un nombre. Los colores en cada colormap se diferencian por su código de color, pero no tienen nombre.
#
# Para poder trabajar con nombres de colores hay que utilizar listas de nombres de colores.
#
# En lo que sigue vamos a acceder a los colores en los colormaps y valos a ver las listas disponibles de nombres de colores.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mpl_colors import MplColors as mplc

# %% [markdown]
# ## Nombres de los colormaps
#
# La función __print_colormaps_names__ nos muestra los nombres de los colormaps disponibles y el número de colores en cada colormap.

# %%
mplc.print_colormaps_names()
# Out:
# Accent: 8 colors, Accent_r: 8 colors, Blues: 256 colors, Blues_r: 256 colors, BrBG: 256 colors
# BrBG_r: 256 colors, BuGn: 256 colors, BuGn_r: 256 colors, BuPu: 256 colors, BuPu_r: 256 colors
# CMRmap: 256 colors, CMRmap_r: 256 colors, Dark2: 8 colors, Dark2_r: 8 colors, GnBu: 256 colors
# GnBu_r: 256 colors, Greens: 256 colors, Greens_r: 256 colors, Greys: 256 colors, Greys_r: 256 colors
# OrRd: 256 colors, OrRd_r: 256 colors, Oranges: 256 colors, Oranges_r: 256 colors, PRGn: 256 colors
# PRGn_r: 256 colors, Paired: 12 colors, Paired_r: 12 colors, Pastel1: 9 colors, Pastel1_r: 9 colors
# Pastel2: 8 colors, Pastel2_r: 8 colors, PiYG: 256 colors, PiYG_r: 256 colors, PuBu: 256 colors
# PuBuGn: 256 colors, PuBuGn_r: 256 colors, PuBu_r: 256 colors, PuOr: 256 colors, PuOr_r: 256 colors
# PuRd: 256 colors, PuRd_r: 256 colors, Purples: 256 colors, Purples_r: 256 colors, RdBu: 256 colors
# RdBu_r: 256 colors, RdGy: 256 colors, RdGy_r: 256 colors, RdPu: 256 colors, RdPu_r: 256 colors
# RdYlBu: 256 colors, RdYlBu_r: 256 colors, RdYlGn: 256 colors, RdYlGn_r: 256 colors, Reds: 256 colors
# Reds_r: 256 colors, Set1: 9 colors, Set1_r: 9 colors, Set2: 8 colors, Set2_r: 8 colors
# Set3: 12 colors, Set3_r: 12 colors, Spectral: 256 colors, Spectral_r: 256 colors, Wistia: 256 colors
# Wistia_r: 256 colors, YlGn: 256 colors, YlGnBu: 256 colors, YlGnBu_r: 256 colors, YlGn_r: 256 colors
# YlOrBr: 256 colors, YlOrBr_r: 256 colors, YlOrRd: 256 colors, YlOrRd_r: 256 colors, afmhot: 256 colors
# afmhot_r: 256 colors, autumn: 256 colors, autumn_r: 256 colors, binary: 256 colors, binary_r: 256 colors
# bone: 256 colors, bone_r: 256 colors, brg: 256 colors, brg_r: 256 colors, bwr: 256 colors
# bwr_r: 256 colors, cividis: 256 colors, cividis_r: 256 colors, cool: 256 colors, cool_r: 256 colors
# coolwarm: 256 colors, coolwarm_r: 256 colors, copper: 256 colors, copper_r: 256 colors, cubehelix: 256 colors
# cubehelix_r: 256 colors, flag: 256 colors, flag_r: 256 colors, gist_earth: 256 colors, gist_earth_r: 256 colors
# gist_gray: 256 colors, gist_gray_r: 256 colors, gist_heat: 256 colors, gist_heat_r: 256 colors, gist_ncar: 256 colors
# gist_ncar_r: 256 colors, gist_rainbow: 256 colors, gist_rainbow_r: 256 colors, gist_stern: 256 colors, gist_stern_r: 256 colors
# gist_yarg: 256 colors, gist_yarg_r: 256 colors, gnuplot2: 256 colors, gnuplot2_r: 256 colors, gnuplot: 256 colors
# gnuplot_r: 256 colors, gray: 256 colors, gray_r: 256 colors, hot: 256 colors, hot_r: 256 colors
# hsv: 256 colors, hsv_r: 256 colors, inferno: 256 colors, inferno_r: 256 colors, jet: 256 colors
# jet_r: 256 colors, magma: 256 colors, magma_r: 256 colors, nipy_spectral: 256 colors, nipy_spectral_r: 256 colors
# ocean: 256 colors, ocean_r: 256 colors, pink: 256 colors, pink_r: 256 colors, plasma: 256 colors
# plasma_r: 256 colors, prism: 256 colors, prism_r: 256 colors, rainbow: 256 colors, rainbow_r: 256 colors
# seismic: 256 colors, seismic_r: 256 colors, spring: 256 colors, spring_r: 256 colors, summer: 256 colors
# summer_r: 256 colors, tab10: 10 colors, tab10_r: 10 colors, tab20: 20 colors, tab20_r: 20 colors
# tab20b: 20 colors, tab20b_r: 20 colors, tab20c: 20 colors, tab20c_r: 20 colors, terrain: 256 colors
# terrain_r: 256 colors, turbo: 256 colors, turbo_r: 256 colors, twilight: 510 colors, twilight_r: 510 colors
# twilight_shifted: 510 colors, twilight_shifted_r: 510 colors, viridis: 256 colors, viridis_r: 256 colors, winter: 256 colors
# winter_r: 256 colors

# %% [markdown]
# ## Ver los colores en cada colormap
#
# Los nombres de los colormaps nos dan una indicación de su contenido, pero lo que nos interesa es ver esos colores. Para esto se utiliza la función __display_colormaps__. Como parámetro es el listado de los colormaps que quieres visualizar. Si no le pasas ningún parámetro, display_colormaps(), se muestran todos los colormaps.

# %%
mplc.display_colormaps(['tab10', 'tab20', 'brg', 'hsv', 'gist_rainbow', 'twilight_shifted'])

# %% [markdown]
# ## Extraer colores de un colormap
#
# En la celda previa vemos todos los colores en cada colormap. Ahora vamos a ver los colores que extraemos de cada colormap cuando hacemos una petición de un número determinado de colores, para lo que se utiliza la función __display_colors_in_colormap__.
#
# La función __display_colors_in_colormap__ tiene tres parámetros, cada uno con un valor por defecto:
#
# * El nombre del colormap (por defecto 'hsv')
# * El número de colores que se van a mostrar (por defecto 10).
# * Si los colores se van a extraer correlativos desde el principio de la lista de colores o se extraerán buscando la máxima separación entre los colores: por ejemplo, si pedimos 3 colores se mostraán el primero, el medio y el útimo)
#
# Si el número de colores que se desean ver excede el de colores en el colormap, habrá puntos con el mismo color.
#
# Haz una prueba utilizando:
#
# * El colormap 'tab10' con 10 puntos y con 20 puntos; verás que con 20 puntos cada dos puntos tienen el mismo color.
# * El colormap 'tab10' con 3 puntos y asignado al parámetro correlative los valores Tue y False

# %%
mplc.display_colors_in_colormap('tab10', 3, correlative=True)
# Out:
# Colormap tab10: number of colors 10. 3 colors are displayed
# Color codes. Formats: RGBA, hex. RGBA
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 1.0), #1f77b4ff
# (1.0, 0.4980392156862745, 0.054901960784313725, 1.0), #ff7f0eff
# (0.17254901960784313, 0.6274509803921569, 0.17254901960784313, 1.0), #2ca02cff

# %% [markdown]
# # Colores con nombre
#
# Se puede asignar colores mediante nombres en vez de por su código de color. Para ello matplotlib suministra unas tables de colores con nombre. Las tablas de colores disponibles son:
